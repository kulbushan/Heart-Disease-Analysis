# %% [markdown]
# # Analysis of UEFA Euro 2012

# %%
import pandas as pd
euro12 = pd.read_csv('https://raw.githubusercontent.com/jokecamp/FootballData/master/UEFA_European_Championship/Euro%202012/Euro%202012%20stats%20TEAM.csv')
euro12.shape
# Out:
# (16, 35)

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro12.isnull().sum().sum()
# Out:
# 1

# %%
euro12[euro12.isnull().any(axis=1)]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0  Croatia      4               13                12             51.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 0                     0      ...               13                 81.3%
#
#    Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 0         41             62         2             9          0        9
#
#    Subs off  Players Used
# 0         9            16
#
# [1 rows x 35 columns]

# %%
euro12.columns[euro12.isnull().any()]
# Out:
# Index(['Clearances off line'], dtype='object')

# %%
euro12[euro12.isnull().any(axis=1)]['Clearances off line']
# Out:
# 0   NaN
# Name: Clearances off line, dtype: float64

# %%
euro12['Clearances off line']
# Out:
# 0     NaN
# 1     2.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     0.0
# 6     0.0
# 7     1.0
# 8     0.0
# 9     0.0
# 10    0.0
# 11    1.0
# 12    0.0
# 13    0.0
# 14    0.0
# 15    0.0
# Name: Clearances off line, dtype: float64

# %%
euro12.loc[:, euro12.isnull().any()]
# Out:
#     Clearances off line
# 0                   NaN
# 1                   2.0
# 2                   0.0
# 3                   1.0
# 4                   0.0
# 5                   0.0
# 6                   0.0
# 7                   1.0
# 8                   0.0
# 9                   0.0
# 10                  0.0
# 11                  1.0
# 12                  0.0
# 13                  0.0
# 14                  0.0
# 15                  0.0

# %%
euro12.fillna(0,  inplace=True)

# %%
euro12.isnull().sum().sum()
# Out:
# 0

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']].sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
euro12[['Team','Goals']].sort_values(['Goals'], ascending = False)
# Out:
#                    Team  Goals
# 13                Spain     12
# 5               Germany     10
# 7                 Italy      6
# 10             Portugal      6
# 3               England      5
# 6                Greece      5
# 12               Russia      5
# 14               Sweden      5
# 0               Croatia      4
# 1        Czech Republic      4
# 2               Denmark      4
# 4                France      3
# 8           Netherlands      2
# 9                Poland      2
# 15              Ukraine      2
# 11  Republic of Ireland      1

# %%
# %matplotlib inline

# %%
euro12[['Team','Goals']].plot()

# %% [markdown]
# ## Observation
# The more goals made, the better team is. Spain won Euro 12.
